# %%
import folium
import pandas as pd

# %%
matched_edges_file = "../data/chengdu/matched_edges.csv"
df = pd.read_csv(matched_edges_file, sep=";")
df.dropna(how="any", inplace=True)

# %%
df
# Out:
#           fid           u           v  \
# 0          22  8574992402  6269858676
# 1          23  8574992402  8574992403
# 2          25  8574992403   471193341
# 3          27  8574992403  8574992404
# 4          28  8574992404  8574992405
# ...       ...         ...         ...
# 43630  151880  4771151802  3015489111
# 43631  151882  4771151802  4771151803
# 43632  151885  4771151803  4771151802
# 43633  151886  4771151803  4771151803
# 43634  151887  4771151803  4771151803
#
#                                                 geometry  points
# 0      LINESTRING (104.1789301 30.5911535, 104.179064...       2
# 1      LINESTRING (104.1789301 30.5911535, 104.179717...       3
# 2      LINESTRING (104.1812774 30.5894974, 104.181362...       2
# 3      LINESTRING (104.1812774 30.5894974, 104.182451...       3
# 4      LINESTRING (104.1840102 30.5876395, 104.184151...       2
# ...                                                  ...     ...
# ...

# %%
df.geometry[0]
# Out:
# 'LINESTRING (104.1789301 30.5911535, 104.1790646 30.5912271)'

# %%
def extract_list_of_points(mgeom):
    # print(mgeom)
    line_str = mgeom.replace("LINESTRING (", "[(").replace(")", ")]").replace(", ", "),(").replace(" ", ",")
    points = eval(line_str)
    if len(points[0]) == 0:
        return []
    points = list(map(lambda x: [x[1], x[0]], points))
    return points

# %%
df["folium_lines"] = df.apply(lambda row: extract_list_of_points(row.geometry), axis=1)

# %%
len(df[df.geometry == "LINESTRING()"]) / len(df)
# Out:
# 0.0

# %%
df
# Out:
#           fid           u           v  \
# 0          22  8574992402  6269858676
# 1          23  8574992402  8574992403
# 2          25  8574992403   471193341
# 3          27  8574992403  8574992404
# 4          28  8574992404  8574992405
# ...       ...         ...         ...
# 43630  151880  4771151802  3015489111
# 43631  151882  4771151802  4771151803
# 43632  151885  4771151803  4771151802
# 43633  151886  4771151803  4771151803
# 43634  151887  4771151803  4771151803
#
#                                                 geometry  points  \
# 0      LINESTRING (104.1789301 30.5911535, 104.179064...       2
# 1      LINESTRING (104.1789301 30.5911535, 104.179717...       3
# 2      LINESTRING (104.1812774 30.5894974, 104.181362...       2
# 3      LINESTRING (104.1812774 30.5894974, 104.182451...       3
# 4      LINESTRING (104.1840102 30.5876395, 104.184151...       2
# ...                                                  ...     ...
# ...

# %%
m = folium.Map(location=[41.1459905, -8.6122327])

# %%
points_list = df.folium_lines
for pl in points_list:
    # folium.Marker(pl[0]).add_to(m)
    # folium.Marker(pl[-1], icon=folium.Icon(color="green")).add_to(m)
    folium.PolyLine(pl).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
